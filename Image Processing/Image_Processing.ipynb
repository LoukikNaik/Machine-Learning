# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil=Image.open("thor1.jpeg")

# %%
arr=np.array(pil)

# %%
arr.shape
# Out:
# (246, 220, 3)

# %%
pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x246 at 0x7FE95811E850>

# %%
cut=arr[:100,:100]

# %%
plt.imshow(cut)

# %%
work=arr.copy()

# %%
work[:,:,[1,2]]=0

# %%
plt.imshow(work)

# %%
gray=arr.mean(axis=2)

# %%
plt.imshow(gray,cmap="gray")
