# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
frame=cv2.imread("thor1.jpeg")

# %%
plt.imshow(frame)

# %%
rgb = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(rgb)

# %%
classifier=cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

# %%
faces=classifier.detectMultiScale(frame)

# %%
face=faces[0]

# %%
x,y,w,h=face

# %%
face=rgb[y:y+h,x:x+w]

# %%
plt.imshow(face)

# %%
out=cv2.rectangle(rgb,(x,y),(x+w,y+h),(0,0,255),4)

# %%
plt.imshow(out)

# %%
a=np.random.randint(1,10,(8,2,1))
b=np.random.randint(1,10,(2,4))
a+b
# Out:
# array([[[14, 17, 11, 14],
#         [14, 10, 15, 11]],
#
#        [[ 7, 10,  4,  7],
#         [ 8,  4,  9,  5]],
#
#        [[ 9, 12,  6,  9],
#         [12,  8, 13,  9]],
#
#        [[12, 15,  9, 12],
#         [15, 11, 16, 12]],
#
#        [[ 8, 11,  5,  8],
#         [13,  9, 14, 10]],
#
#        [[ 8, 11,  5,  8],
#         [13,  9, 14, 10]],
#
#        [[13, 16, 10, 13],
#         [14, 10, 15, 11]],
#
#        [[14, 17, 11, 14],
#         [11,  7, 12,  8]]])
